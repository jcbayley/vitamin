# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("/home/joseph.bayley/public_html/CBC/vitamin_O4MDC/vitamin_fit_c_run6_1024_tanhdata_widespin_compnet1_cycliclearn/loss.txt","rb") as f:
    cyc1 = np.loadtxt(f)

# %%
with open("/home/joseph.bayley/public_html/CBC/vitamin_O4MDC/vitamin_fit_c_run6_1024_tanhdata_widespin_compnet4_cycliclearn/loss.txt","rb") as f:
    cyc4 = np.loadtxt(f)

# %%
with open("/home/joseph.bayley/public_html/CBC/vitamin_O4MDC/vitamin_fit_c_run6_1024_tanhdata_widespin_compnet4_no_cycliclearn/loss.txt","rb") as f:
    nocyc4 = np.loadtxt(f)

# %%
with open("/home/joseph.bayley/public_html/CBC/vitamin_O4MDC/vitamin_fit_c_run6_1024_tanhdata_widespin_compnet5_cycliclearn/loss.txt","rb") as f:
    cyc5 = np.loadtxt(f)

# %%
with open("/home/joseph.bayley/public_html/CBC/vitamin_O4MDC/vitamin_fit_c_run6_1024_tanhdata_widespin_compnet5_no_cycliclearn/loss.txt","rb") as f:
    nocyc5 = np.loadtxt(f)

# %%
with open("/home/joseph.bayley/public_html/CBC/vitamin_O4MDC/vitamin_fit_c_run6_1024_tanhdata_widespin_compnet5_no_cycliclearn_noramp/loss.txt","rb") as f:
    nocyc5_noramp = np.loadtxt(f)

# %%
cyc4[100]
# Out:
# array([-19.25343704, 159.2616272 , -19.25343704, -19.23521423,
#        157.23986816, -19.23521423])

# %%
fig, ax  = plt.subplots(figsize = (20,10))
endind = 10000
lossind = 2
ax.plot(cyc4[:endind,lossind],color="C0")
ax.plot(nocyc4[:,lossind],color="C0", ls="--")
ax.plot(cyc5[:endind,lossind],color="C1", ls="-")
ax.plot(nocyc5[:,lossind],color="C1", ls="--")
ax.plot(nocyc5_noramp[:,lossind],color="C2", ls="--")
ax.set_xscale("log")

# %%
fig, ax  = plt.subplots(figsize = (20,10))
endind = 10000
lossind = 5
ax.plot(cyc4[:endind,lossind],color="C0")
ax.plot(nocyc4[:,lossind],color="C0", ls="--")
ax.plot(cyc5[:endind,lossind],color="C1", ls="-")
ax.plot(nocyc5[:,lossind],color="C1", ls="--")
ax.plot(nocyc5_noramp[:,lossind],color="C2", ls="--")
ax.set_xscale("log")

# %%
with open("/home/joseph.bayley/public_html/CBC/vitamin_O4MDC/vitamin_fit_c_run6_1024_tanhdata_widespin_lr_test/loss.txt","rb") as f:
    lrtest = np.loadtxt(f)

# %%
len(lrtest)
# Out:
# 100

# %%
fig, ax = plt.subplots(figsize = (20,10))
xs = np.linspace(-9,-1,200)
expxs = 10**xs
ax.plot(xs[:len(lrtest)],lrtest[:,5])
